# %% [markdown]
# # INITIAL IMPLEMENTATION OF WORDGRAPH2VEC ALGORITHM
#
# WordGraph2Vec algorithm in skip-gram model (TF Implementation)

# %% [markdown]
# Most skip-gram W2V + embedding lookup table and negative sampling are included in tensorflow:
# ```
# tf.nn.embedding_lookup
# tf.nn.sampled_softmax_loss
# ```
#
# Steps:
#
# 1.   <b>Preprocessing</b><br>
# Tokenize input and convert input into INT representation. Have look ups: <br> word $→$ int index
# 2.   <b>Subsampling</b> <br>
# Words (e.g stopwords) does not provide much context of words nearby. Discard them to remove some of the noise from our data, get faster training and better representation. i.e Subsampling by Mikolov (Discard word in training set, discard it with probability: p(word) = 1 - sqrt(threshold/freq(word))
# 3.   **Sampling Table**:
# ```
# inputs and labels
# ```
# **labels** = 2dim required by `tf.nn.sampled_softmax_loss` used for negative sampling.<br>
# **embedding matrix** = [number_of_words x number_of_units(hidden layer)]
# $→$ if 10000 words and 300 hidden units matrix will have size $10000\times 300$
# **tokenized words** = input ~⏯ tokenized data of inputs (integers = # of words in vocabulary)
# 4.   **Negative Sampling**<br>
# Update the weights for correct label, only a small number of incorrect labels (negative sampling) `tf.nn.sampled_softmax_loss`
# 5.   Visualization

# %% [markdown]
# One hot encoding thousands of classes to predict each word is massively inefficient. Matrix multiplication going into first hidden layer will almost all of resulting values be zero.(Sparse)
#
# Idea: Get embeddings weights from an embedding layer. One-hot encoded vector with a matrix return row of matrix corresponding the index of the on input unit. Weight Matrix = lookup table, encode the words as integers and then get the index $i^{th}$ = embedding lookup and the # of hidden units is embedding dimension.
#
# Embedding lookup is weight matrix.
#
# Embedding layer is a hidden layer. Lookup is a shortcut for matrix. Embedding layer is just a hidden layer. (Embeddings used only for Words that contain semantic meaning)

# %% [markdown]
# ## Word2Vec
#
# Finds efficient representations (vectors that represent the words) = Vectors also contain semantic information about the words. <br>
# e.g black whte red will have vectors near each other.

# %%
import time
import numpy as np
# import tensorflow as tf
import tensorflow.compat.v1 as tf
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

# %%
dataset_folder_path = 'content'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)

with open('content/text8') as f:
    text = f.read()

# %% [markdown]
# ### Preprocessing
#
# - Convert any punctuation into tokens.
# - Remove words that show up 5 times or less in dataset (Reduce noise and improve quality of the vector)

# %%
import re
from collections import Counter
def preprocess(text):
    # Replace punctuation with tokens so we can use them in our model
    text = text.lower()
    text = text.replace('.', ' <PERIOD> ')
    text = text.replace(',', ' <COMMA> ')
    text = text.replace('"', ' <QUOTATION_MARK> ')
    text = text.replace(';', ' <SEMICOLON> ')
    text = text.replace('!', ' <EXCLAMATION_MARK> ')
    text = text.replace('?', ' <QUESTION_MARK> ')
    text = text.replace('(', ' <LEFT_PAREN> ')
    text = text.replace(')', ' <RIGHT_PAREN> ')
    text = text.replace('--', ' <HYPHENS> ')
    text = text.replace('?', ' <QUESTION_MARK> ')
    # text = text.replace('\n', ' <NEW_LINE> ')
    text = text.replace(':', ' <COLON> ')
    words = text.split()
    # Remove all words with  5 or fewer occurences
    word_counts = Counter(words)
    trimmed_words = [word for word in words if word_counts[word] > 5]
    return trimmed_words


def get_batches(int_text, batch_size, seq_length):
    """
    Return batches of input and target
    :param int_text: Text with the words replaced by their ids
    :param batch_size: The size of batch
    :param seq_length: The length of sequence
    :return: A list where each item is a tuple of (batch of input, batch of target).
    """
    n_batches = int(len(int_text) / (batch_size * seq_length))
    # Drop the last few characters to make only full batches
    xdata = np.array(int_text[: n_batches * batch_size * seq_length])
    ydata = np.array(int_text[1: n_batches * batch_size * seq_length + 1])
    x_batches = np.split(xdata.reshape(batch_size, -1), n_batches, 1)
    y_batches = np.split(ydata.reshape(batch_size, -1), n_batches, 1)
    return list(zip(x_batches, y_batches))


def create_lookup_tables(words):
    """
    Create lookup tables for vocabulary
    :param words: Input list of words
    :return: A tuple of dicts.  The first dict....
    """
    word_counts = Counter(words)
    sorted_vocab = sorted(word_counts, key=word_counts.get, reverse=True)
    int_to_vocab = {ii: word for ii, word in enumerate(sorted_vocab)}
    vocab_to_int = {word: ii for ii, word in int_to_vocab.items()}
    return vocab_to_int, int_to_vocab

# %%
words = preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %%
vocab_to_int, int_to_vocab = create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %%
int_to_vocab[int_words[0]]
# Out:
# 'anarchism'

# %% [markdown]
# ### Subsampling
#
# Discard some of the stopwords as they do not provide a lot of context for nearby words. $⇒$ Faster training, better representation and less noise.
#
# $⇒$ Subsampling
#
# For each word $w_i$ in dataset discard it with probability of:
# $$
# P(w_i) = 1 - \sqrt(\frac{t}{f(w_i})
# $$

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %% [markdown]
# ### Making data for training (Batches of words)
#
# Skip-Gram: Each word in text grap all words in a window around that word (Size C) Distant words are less related to the current words close to it (less weight to distant words by sampling less from those words in our training example)
#
# If `win_size = 5` for each training word we select randomly a number R in range [1, C] and then use R words from history and R words from future of current word as correct label = 1

# %%
def get_target(words, idx, win_size=5):
    ''' Get a list of words in a window around an index '''
    R = np.random.randint(1, win_size + 1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx + 1: stop + 1])
    return list(target_words)

# %%
def get_batches(words, batch_size, win_size=5):
    '''
    Create a generator of word batches as a tuple (inputs, targets)
    '''
    n_batches = len(words)//batch_size
    words = words[:n_batches * batch_size]
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, win_size)
            y.extend(batch_y)
            x.extend([batch_x] * len(batch_y))
        yield x, y

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.compat.v1.placeholder(tf.int32, [None], name='inputs')
    labels = tf.compat.v1.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ### Embeddings
#
# Size : [# of words x # of hidden units]<br>
# Tokenized data as input (# of tokens == # of words)
#
#
# `tf.nn.embedding_lookup` = pass in embedding matrix and a tensor of integers and it returns rows in the matrix corresponding to those integers.
#
# <br>
# # of embeddings = 200
# <br>
# Create embeddin matrix variable and use tf.nn.embedding_lookup to get embedding tensors. For embedding matrix (initialize it with a uniform random number between -1 and 1 using `tf.random_uniform`)

# %%
n_vocab = len(int_to_vocab)
# print(n_vocab)
n_embedding = 200 # num of embedding features
with train_graph.as_default():
    embedding = tf.compat.v1.Variable(tf.compat.v1.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.compat.v1.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ### Negative Sampling
#
# For every example we give the network we train it using output of softmax layer
#
# For each input we make very small changes to millions of weights even though we have only one true example.
#
# This makes training the network inefficient.
#
# We can approximate the loss from softmax layer by only updating a small subset of all weigths at once.  $⇒$ update weights for correct label but only a small number of incorrect labels == Negative Sampling
#
# `tf.nn.sampled_softmax_loss`

# %%
# Create weights and biases for softmax layer
# Use tf.nn.sampled_softmax_loss to calculate the loss

n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.compat.v1.Variable(tf.compat.v1.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.compat.v1.Variable(tf.compat.v1.zeros(n_vocab))
    # Calculate the loss using negative sampling
    loss = tf.compat.v1.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    cost = tf.compat.v1.reduce_mean(loss)
    optimizer = tf.compat.v1.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ### Validation
#
# Chose a few common words and few uncommon words. Then we will print out the closest words to them. It's a nice way to check that the embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    # Random set of words to evaluate similarity on
    valid_size = 16
    valid_window = 100
    # Pick 8 samples from (0,100) and (1000, 1100) each ranges
    # Lower ids implies more frequent
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples,
                               random.sample(range(1000, 1000 + valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # We use the cosine distance:
    norm = tf.sqrt(tf.compat.v1.reduce_sum(tf.compat.v1.square(embedding), 1, keepdims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.compat.v1.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.compat.v1.matmul(valid_embedding, tf.compat.v1.transpose(normalized_embedding))

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.compat.v1.train.Saver()

with tf.compat.v1.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.compat.v1.global_variables_initializer())

    for e in tqdm(range(1, epochs+1)):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:

            feed = {inputs: x, labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)

            loss += train_loss

            if iteration % 100 == 0:
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()

            if iteration % 1000 == 0:
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)

            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6647 0.2929 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6407 0.2911 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5331 0.2920 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5721 0.2915 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5379 0.2907 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5234 0.2899 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5497 0.2934 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5489 0.2903 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4636 0.2910 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4274 0.2915 sec/batch
# Nearest to it: testable, bloc, kazakhstan, corrupting, chloroplasts, defibrillator, daito, adrenergic,
# Nearest to can: private, specimens, blight, prevent, superpowered, bernese, surpassed, leah,
# Nearest to also: wargame, grier, confessed, mesures, becket, sally, macgillivray, diffracted,
# Nearest to only: flax, chessboard, oppositional, constants, fashioned, pigeons, salvadoran, hyperspace,
# Nearest to years: qinghai, seven, gods, wilmette, dredged, intimidated, speeches, geographically,
# Nearest to he: draws, buckle, lodges, itching, karakoram, ecumenical, belated, jameson,
# Nearest to over: joel, uncharacteristic, finkelstein, banchan, hs, umbra, lyotropic, mishna,
# Nearest to about: cpus, audubon, kowloon, lector, fell, reclassified, kampf, romania,
# Nearest to taking: immunosuppressive, electorate, coleridge, myrtle, demosthenes, television, orchard, unbeknownst,
# Nearest to units: emb, figures, pink, live, unsteady, schaff, tatiana, deeper,
# Nearest to professional: burr, damasio, lichtenstein, clostridium, overillumination, introductions, costly, tristar,
# Nearest to file: bromley, replies, ure, gisela, mindset, million, color, gatehouse,
# Nearest to behind: admonitions, methadone, overran, hci, affecting, gaelic, loris, thereupon,
# Nearest to consists: drain, oates, raziel, bassist, saxony, neglect, uma, d,
# Nearest to lived: rwandan, mayotte, telemark, outpouring, ndb, hercegovina, genocide, globicephala,
# Nearest to marriage: preslar, sceptre, inf, wolfowitz, deep, sims, triads, gateless,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4772 0.2934 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3727 0.2904 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3193 0.2910 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2630 0.2912 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1895 0.2927 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1213 0.2899 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1060 0.2909 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0826 0.2904 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9826 0.2908 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 5.0055 0.2917 sec/batch
# Nearest to it: bloc, none, hermaphrodite, testable, truly, kazakhstan, aside, doctor,
# Nearest to can: private, specimens, prevent, restored, surpassed, importation, superpowered, unable,
# Nearest to also: confessed, grier, according, testimony, becket, look, wargame, pins,
# Nearest to only: flax, constants, fashioned, hyperspace, chessboard, have, biggest, overlap,
# Nearest to years: seven, qinghai, gods, geographically, speeches, randomly, bottom, billy,
# Nearest to he: draws, title, ecumenical, dispute, buckle, house, jameson, claims,
# Nearest to over: today, hs, joel, finkelstein, touching, banchan, check, differential,
# Nearest to about: cpus, fell, lector, romania, encrypt, almost, audubon, niagara,
# Nearest to taking: immunosuppressive, television, paris, electorate, reporter, skeptical, immigrants, speculators,
# Nearest to units: figures, pink, live, emb, deeper, stalin, unsteady, massacre,
# Nearest to professional: burr, lichtenstein, clostridium, unsportsmanlike, grammar, damasio, football, introductions,
# Nearest to file: bromley, replies, million, coppersmith, color, gisela, carolyn, mindset,
# Nearest to behind: admonitions, four, affecting, account, christians, methadone, overran, sham,
# Nearest to consists: drain, raziel, d, bassist, neglect, saxony, due, unusable,
# Nearest to lived: rwandan, genocide, opened, mayotte, aquarists, lewis, process, telemark,
# Nearest to marriage: deep, sceptre, preslar, sims, have, inf, wolfowitz, supersede,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9235 0.2930 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8909 0.2908 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8930 0.2916 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8641 0.2939 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8181 0.2901 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.7805 0.2914 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7920 0.2915 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7894 0.2923 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7929 0.2931 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7863 0.2916 sec/batch
# Nearest to it: testable, truly, bloc, none, aside, caste, photosynthesis, doctor,
# Nearest to can: private, specimens, superpowered, prevent, surpassed, layer, operas, importation,
# Nearest to also: confessed, grier, becket, sally, testimony, wargame, according, macgillivray,
# Nearest to only: constants, chessboard, fashioned, flax, gangs, salvadoran, caricom, hyperspace,
# Nearest to years: seven, gods, speeches, qinghai, geographically, billy, negligible, randomly,
# Nearest to he: draws, dispute, title, ecumenical, lay, masters, belated, lodges,
# Nearest to over: joel, hs, uncharacteristic, today, differential, finkelstein, banchan, insofar,
# Nearest to about: cpus, fell, encrypt, audubon, lector, kowloon, romania, reclassified,
# Nearest to taking: immunosuppressive, electorate, television, paris, immigrants, skeptical, reporter, orchard,
# Nearest to units: figures, pink, emb, stalin, unsteady, schaff, deeper, live,
# Nearest to professional: burr, lichtenstein, grammar, costly, football, clostridium, unsportsmanlike, introductions,
# Nearest to file: bromley, carolyn, replies, color, million, gisela, coppersmith, begin,
# Nearest to behind: overran, admonitions, affecting, methadone, hci, christians, four, gaelic,
# Nearest to consists: drain, raziel, bassist, neglect, saxony, d, jews, expenditure,
# Nearest to lived: rwandan, genocide, migrant, chiefly, svinhufvud, aquarists, lewis, posing,
# Nearest to marriage: sceptre, deep, preslar, sims, have, inf, taxpayer, wolfowitz,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7658 0.2918 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7512 0.2928 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7364 0.2904 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7057 0.2899 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7277 0.2912 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6927 0.2916 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7090 0.2911 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7144 0.2903 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7160 0.2903 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6812 0.2923 sec/batch
# Nearest to it: testable, truly, photosynthesis, advising, intrigued, caste, daito, kazakhstan,
# Nearest to can: private, superpowered, specimens, layer, demystified, prevent, theoretician, operas,
# Nearest to also: confessed, strains, becket, grier, boron, macgillivray, according, wargame,
# Nearest to only: gangs, chessboard, fashioned, constants, flax, hyperspace, ww, clockwise,
# Nearest to years: seven, gods, speeches, migration, total, brazilian, wilmette, qinghai,
# Nearest to he: draws, title, lay, ecumenical, dispute, masters, lodges, buckle,
# Nearest to over: joel, uncharacteristic, today, hs, finkelstein, banchan, intend, mishna,
# Nearest to about: cpus, audubon, lector, fell, encrypt, kowloon, romania, albanian,
# Nearest to taking: immunosuppressive, electorate, coleridge, skeptical, myrtle, demosthenes, immigrants, variance,
# Nearest to units: emb, figures, pink, deeper, unsteady, stalin, megalithic, schaff,
# Nearest to professional: burr, football, lichtenstein, costly, grammar, introductions, clostridium, unsportsmanlike,
# Nearest to file: carolyn, bromley, replies, color, mindset, gisela, ure, platform,
# Nearest to behind: methadone, admonitions, overran, affecting, gaelic, hci, already, thereupon,
# Nearest to consists: drain, neglect, oates, raziel, bassist, saxony, skinny, foggy,
# Nearest to lived: rwandan, genocide, svinhufvud, lewis, migrant, telemark, aida, meaningless,
# Nearest to marriage: sceptre, preslar, deep, sims, wolfowitz, inf, have, payment,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6681 0.2918 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6808 0.2908 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6176 0.2909 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6450 0.2910 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6160 0.2917 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6500 0.2905 sec/batch
#  10%|█         | 1/10 [22:28<3:22:17, 1348.65s/it]
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6113 0.2109 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5352 0.2937 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5107 0.2922 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5150 0.2914 sec/batch
# Nearest to it: testable, truly, photosynthesis, intrigued, advising, daito, phaenomena, hermaphrodite,
# Nearest to can: private, layer, superpowered, specimens, prevent, demystified, different, operas,
# Nearest to also: strains, confessed, boron, becket, macgillivray, wargame, grier, appalachia,
# Nearest to only: gangs, chessboard, clockwise, anglia, brightest, salvadoran, hyperspace, constants,
# Nearest to years: seven, migration, gods, total, speeches, brazilian, wilmette, billy,
# Nearest to he: draws, his, title, buckle, lay, lodges, belated, ecumenical,
# Nearest to over: uncharacteristic, intend, today, angleton, mishna, joel, finkelstein, weakly,
# Nearest to about: audubon, cpus, encrypt, lector, kowloon, fell, kampf, baralong,
# Nearest to taking: immunosuppressive, electorate, demosthenes, coleridge, myrtle, variance, skeptical, stimuli,
# Nearest to units: emb, transposing, pink, figures, tatiana, deeper, quadrivium, break,
# Nearest to professional: football, burr, lichtenstein, introductions, costly, grammar, clostridium, camira,
# Nearest to file: carolyn, bromley, platform, color, replies, mindset, pulses, integers,
# Nearest to behind: methadone, admonitions, overran, affecting, already, gaelic, abrasive, hci,
# Nearest to consists: neglect, drain, oates, raziel, foggy, anchors, skinny, expenditure,
# Nearest to lived: rwandan, genocide, svinhufvud, mayotte, telemark, aida, migrant, austrians,
# Nearest to marriage: sceptre, payment, preslar, wolfowitz, have, ize, inf, preside,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4867 0.2925 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4909 0.2907 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4764 0.2912 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5115 0.2911 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4929 0.2913 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4644 0.2917 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4681 0.2917 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4013 0.2926 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4439 0.2930 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4523 0.2925 sec/batch
# Nearest to it: testable, satisfiability, intrigued, photosynthesis, truly, phaenomena, none, platforms,
# Nearest to can: layer, private, superpowered, different, prevent, techniques, endosymbiotic, specimens,
# Nearest to also: strains, boron, wargame, according, confessed, macgillivray, becket, appalachia,
# Nearest to only: chessboard, gangs, have, clockwise, hyperspace, constants, fashioned, brightest,
# Nearest to years: seven, total, migration, gods, wilmette, expectancy, brazilian, depressing,
# Nearest to he: his, title, draws, lay, ecumenical, lodges, buckle, electrotechnical,
# Nearest to over: today, intend, angleton, uncharacteristic, finkelstein, disposal, mishna, weakly,
# Nearest to about: audubon, cpus, kowloon, baralong, fell, lector, encrypt, skit,
# Nearest to taking: demosthenes, immunosuppressive, electorate, myrtle, coleridge, variance, skeptical, benefit,
# Nearest to units: emb, transposing, gauge, pink, combustion, machinery, sala, quadrivium,
# Nearest to professional: football, burr, lichtenstein, introductions, costly, clostridium, cyclopedia, pursuit,
# Nearest to file: color, carolyn, bromley, platform, pulses, computer, replies, aphasia,
# Nearest to behind: methadone, admonitions, overran, affecting, already, shen, muds, gaelic,
# Nearest to consists: neglect, drain, oates, raziel, anchors, skinny, expenditure, ile,
# Nearest to lived: rwandan, genocide, mayotte, svinhufvud, celibate, austrians, aramaeans, aida,
# Nearest to marriage: payment, sceptre, wolfowitz, preslar, preside, ize, inf, taxpayer,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4249 0.2929 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4083 0.2923 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4356 0.2910 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3864 0.2909 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4072 0.2923 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4240 0.2910 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3812 0.2920 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3481 0.2919 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4465 0.2914 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3593 0.2916 sec/batch
# Nearest to it: testable, satisfiability, intrigued, photosynthesis, phaenomena, truly, censorship, none,
# Nearest to can: private, layer, superpowered, demystified, different, endosymbiotic, techniques, specimens,
# Nearest to also: strains, boron, macgillivray, according, wargame, grier, methodists, confessed,
# Nearest to only: have, chessboard, gangs, hyperspace, clockwise, salvadoran, brightest, some,
# Nearest to years: seven, total, migration, expectancy, wilmette, hitchens, gods, regrettable,
# Nearest to he: his, title, draws, ecumenical, lay, garfield, electrotechnical, buckle,
# Nearest to over: intend, disposal, angleton, uncharacteristic, today, orapa, hs, bougainville,
# Nearest to about: audubon, baralong, kowloon, cpus, skit, kampf, encrypt, constructs,
# Nearest to taking: demosthenes, electorate, immunosuppressive, coleridge, benefit, variance, undergone, myrtle,
# Nearest to units: emb, transposing, gauge, diverted, combustion, measurements, pink, joule,
# Nearest to professional: football, burr, lichtenstein, introductions, costly, cyclopedia, expandability, pursuit,
# Nearest to file: platform, pulses, carolyn, color, computer, numerical, technical, replies,
# Nearest to behind: methadone, admonitions, overran, snap, gaelic, already, horatio, four,
# Nearest to consists: neglect, drain, anchors, timestamp, expenditure, photonic, raziel, ile,
# Nearest to lived: rwandan, genocide, svinhufvud, celibate, austrians, aramaeans, ruickbie, aida,
# Nearest to marriage: wolfowitz, payment, sceptre, preslar, preside, have, ize, condemned,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3757 0.2938 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.4060 0.2913 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3511 0.2912 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3578 0.2909 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3920 0.2907 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3408 0.2925 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3684 0.2911 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3854 0.2920 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3228 0.2918 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3367 0.2919 sec/batch
# Nearest to it: testable, satisfiability, truly, phaenomena, solidly, censorship, photosynthesis, geddes,
# Nearest to can: private, superpowered, layer, demystified, operas, primates, specimens, prevent,
# Nearest to also: strains, boron, according, rr, macgillivray, wargame, gohan, grier,
# Nearest to only: have, gangs, hyperspace, chessboard, clockwise, salvadoran, constants, some,
# Nearest to years: seven, total, migration, expectancy, hitchens, wilmette, regrettable, male,
# Nearest to he: his, draws, title, lay, ecumenical, buckle, belated, returned,
# Nearest to over: angleton, uncharacteristic, disposal, intend, finkelstein, orapa, lyotropic, today,
# Nearest to about: audubon, kowloon, baralong, historians, skit, copernicus, cpus, constructs,
# Nearest to taking: demosthenes, immunosuppressive, electorate, myrtle, variance, coleridge, benefit, undergone,
# Nearest to units: emb, diverted, transposing, gauge, combustion, joule, speller, measurements,
# Nearest to professional: football, burr, lichtenstein, introductions, expandability, cyclopedia, franchises, express,
# Nearest to file: platform, isdn, technical, pulses, color, computer, numerical, carolyn,
# Nearest to behind: methadone, overran, snap, admonitions, already, shen, refrain, thereupon,
# Nearest to consists: drain, neglect, anchors, photonic, ile, foggy, sectional, timestamp,
# Nearest to lived: rwandan, genocide, svinhufvud, ruickbie, celibate, aramaeans, liguria, aida,
# Nearest to marriage: wolfowitz, payment, preside, sceptre, preslar, condemned, shelved, browski,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3396 0.2939 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3013 0.2928 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3739 0.2921 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.4052 0.2913 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3906 0.2918 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2904 0.2928 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3154 0.2907 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3456 0.2916 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2293 0.2928 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3100 0.2926 sec/batch
# Nearest to it: testable, phaenomena, intrigued, satisfiability, geddes, truly, solidly, humanely,
# Nearest to can: superpowered, private, layer, demystified, operas, primates, specimens, cvc,
# Nearest to also: strains, boron, gohan, rr, macgillivray, grimoire, diffracted, wargame,
# Nearest to only: have, hyperspace, chessboard, gangs, clockwise, salvadoran, grandpa, incurable,
# Nearest to years: migration, total, seven, expectancy, male, hitchens, wilmette, children,
# Nearest to he: his, title, draws, buckle, ecumenical, lodges, moments, returned,
# Nearest to over: angleton, longbows, finkelstein, uncharacteristic, lyotropic, intend, orapa, bougainville,
# Nearest to about: audubon, kowloon, baralong, historians, skit, copernicus, monotheist, lector,
# Nearest to taking: demosthenes, immunosuppressive, variance, coleridge, electorate, myrtle, consented, benefit,
# Nearest to units: emb, diverted, transposing, combustion, joule, gauge, measurements, speller,
# Nearest to professional: football, burr, cyclopedia, lichtenstein, expandability, introductions, express, franchises,
# Nearest to file: platform, isdn, technical, pulses, aphasia, numerical, download, carolyn,
# Nearest to behind: methadone, overran, snap, admonitions, already, shen, refrain, gunned,
# Nearest to consists: drain, ile, neglect, photonic, foggy, sectional, anchors, veto,
# Nearest to lived: rwandan, svinhufvud, celibate, genocide, ruickbie, liguria, superheroic, bibliotheke,
# Nearest to marriage: wolfowitz, payment, preslar, preside, sceptre, shelved, have, ize,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2892 0.2943 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3047 0.2906 sec/batch
#  20%|██        | 2/10 [44:59<3:00:01, 1350.13s/it]
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3290 0.1285 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2474 0.2907 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2208 0.2924 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.1642 0.2927 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2179 0.2913 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2133 0.2907 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2256 0.2918 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1869 0.2916 sec/batch
# Nearest to it: testable, bloc, humanely, satisfiability, solidly, phaenomena, intrigued, censorship,
# Nearest to can: superpowered, private, layer, primates, miracles, specimens, endosymbiotic, operas,
# Nearest to also: strains, macgillivray, gohan, grimoire, rr, diffracted, wargame, ahu,
# Nearest to only: chessboard, hyperspace, have, gangs, clockwise, incurable, salvadoran, urng,
# Nearest to years: seven, migration, total, expectancy, hitchens, regrettable, brazilian, children,
# Nearest to he: his, ecumenical, lodges, draws, piqued, buckle, title, moments,
# Nearest to over: angleton, uncharacteristic, longbows, finkelstein, orapa, intend, bougainville, lyotropic,
# Nearest to about: audubon, kowloon, baralong, historians, kampf, skit, copernicus, lector,
# Nearest to taking: demosthenes, consented, coleridge, immunosuppressive, variance, electorate, myrtle, undergone,
# Nearest to units: emb, transposing, diverted, combustion, joule, si, gauge, speller,
# Nearest to professional: football, express, franchises, cyclopedia, expandability, introductions, burr, lichtenstein,
# Nearest to file: platform, isdn, technical, astronautica, download, numerical, bundled, ure,
# Nearest to behind: methadone, snap, overran, admonitions, shen, already, gunned, stubby,
# Nearest to consists: drain, ile, neglect, foggy, photonic, veto, expenditure, sectional,
# Nearest to lived: rwandan, celibate, svinhufvud, genocide, ruickbie, liguria, aramaeans, bibliotheke,
# Nearest to marriage: wolfowitz, payment, preside, preslar, sceptre, shelved, browski, outrage,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2457 0.2931 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2204 0.2921 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2078 0.2908 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1451 0.2910 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1912 0.2907 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1612 0.2917 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1688 0.2904 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1729 0.2917 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2070 0.2915 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.2017 0.2914 sec/batch
# Nearest to it: testable, satisfiability, phaenomena, polypropylene, jumpers, intrigued, amazingly, scoreboard,
# Nearest to can: private, superpowered, obstetrics, cvc, operas, niva, primates, layer,
# Nearest to also: strains, gohan, macgillivray, rr, grimoire, boron, according, methodists,
# Nearest to only: hyperspace, have, chessboard, gangs, clockwise, incurable, urng, cyberpunk,
# Nearest to years: seven, migration, total, expectancy, hitchens, children, regrettable, male,
# Nearest to he: his, piqued, draws, moments, ecumenical, buckle, lodges, hardened,
# Nearest to over: angleton, orapa, intend, uncharacteristic, longbows, lyotropic, hs, disposal,
# Nearest to about: audubon, kowloon, baralong, constructs, historians, skit, copernicus, kampf,
# Nearest to taking: demosthenes, consented, electorate, immunosuppressive, coleridge, variance, roam, prelude,
# Nearest to units: transposing, si, emb, diverted, joule, gauge, combustion, measurements,
# Nearest to professional: football, cyclopedia, franchises, express, expandability, lichtenstein, clostridium, foliage,
# Nearest to file: platform, isdn, numerical, download, astronautica, interchanged, carolyn, bundled,
# Nearest to behind: methadone, snap, overran, admonitions, stubby, shen, already, refrain,
# Nearest to consists: drain, ile, photonic, foggy, neglect, veto, timestamp, anchors,
# Nearest to lived: rwandan, celibate, ruickbie, svinhufvud, liguria, aramaeans, genocide, bibliotheke,
# Nearest to marriage: wolfowitz, payment, preside, preslar, sceptre, browski, paid, shelved,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1964 0.2930 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.1992 0.2906 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1725 0.2919 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1637 0.2900 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1562 0.2903 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1903 0.2905 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1772 0.2918 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1712 0.2898 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1136 0.2916 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1944 0.2919 sec/batch
# Nearest to it: testable, phaenomena, satisfiability, censorship, jumpers, intrigued, truly, where,
# Nearest to can: private, superpowered, operas, layer, obstetrics, equivalence, subtracting, niva,
# Nearest to also: strains, gohan, macgillivray, rr, boron, grimoire, according, methodists,
# Nearest to only: have, hyperspace, gangs, chessboard, clockwise, incurable, constants, diverted,
# Nearest to years: seven, migration, total, expectancy, male, children, rate, hitchens,
# Nearest to he: his, piqued, hardened, buckle, draws, belated, greenwood, ecumenical,
# Nearest to over: angleton, orapa, intend, airports, uncharacteristic, longbows, dowland, disposal,
# Nearest to about: audubon, kowloon, constructs, historians, baralong, copernicus, henslow, skit,
# Nearest to taking: demosthenes, consented, electorate, variance, immunosuppressive, prelude, coleridge, unbeknownst,
# Nearest to units: si, joule, transposing, diverted, emb, combustion, measurements, powered,
# Nearest to professional: football, cyclopedia, expandability, express, lichtenstein, franchises, introductions, draw,
# Nearest to file: download, platform, isdn, interchanged, astronautica, collaboratively, carolyn, ega,
# Nearest to behind: methadone, snap, overran, stubby, admonitions, already, shen, refrain,
# Nearest to consists: drain, ile, photonic, louisbourg, veto, foggy, flags, timestamp,
# Nearest to lived: rwandan, celibate, ruickbie, migrant, svinhufvud, liguria, peril, aramaeans,
# Nearest to marriage: wolfowitz, payment, preslar, preside, paid, shelved, sceptre, browski,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1950 0.2932 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1530 0.2926 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.2025 0.2904 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1890 0.2914 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1765 0.2911 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1301 0.2906 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1864 0.2906 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1166 0.2919 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1723 0.2910 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2412 0.2923 sec/batch
# Nearest to it: censorship, phaenomena, bloc, satisfiability, truly, testable, none, where,
# Nearest to can: private, superpowered, miracles, operas, obstetrics, layer, primates, niva,
# Nearest to also: gohan, strains, macgillivray, grier, methodists, rr, according, ahu,
# Nearest to only: have, hyperspace, gangs, chessboard, urng, clockwise, caricom, salvadoran,
# Nearest to years: seven, total, migration, expectancy, rate, children, male, fifteen,
# Nearest to he: his, hardened, returned, greenwood, jameson, draws, piqued, belated,
# Nearest to over: angleton, orapa, longbows, dowland, intend, airports, moonraker, uncharacteristic,
# Nearest to about: historians, kowloon, audubon, baralong, copernicus, henslow, constructs, skit,
# Nearest to taking: demosthenes, consented, coleridge, variance, immunosuppressive, electorate, roam, unbeknownst,
# Nearest to units: si, joule, transposing, diverted, pdi, emb, speller, combustion,
# Nearest to professional: football, cyclopedia, franchises, expandability, express, lichtenstein, introductions, draw,
# Nearest to file: platform, download, isdn, astronautica, collaboratively, interchanged, ega, proxy,
# Nearest to behind: methadone, overran, snap, admonitions, stubby, gunned, abrasive, refrain,
# Nearest to consists: drain, ile, photonic, louisbourg, foggy, distinguish, sukhothai, flags,
# Nearest to lived: rwandan, tempestuous, ruickbie, svinhufvud, liguria, celibate, migrant, bayern,
# Nearest to marriage: payment, paid, wolfowitz, preslar, preside, shelved, chains, browski,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2100 0.2918 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1598 0.2911 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1269 0.2894 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1509 0.2898 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0356 0.2904 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1219 0.2905 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1401 0.2908 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1435 0.2911 sec/batch
#  30%|███       | 3/10 [1:07:27<2:37:24, 1349.18s/it]
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1528 0.0467 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1333 0.2914 sec/batch
# Nearest to it: phaenomena, testable, satisfiability, where, censorship, bloc, intrigued, truly,
# Nearest to can: private, superpowered, operas, layer, primates, obstetrics, miracles, niva,
# Nearest to also: gohan, strains, macgillivray, grier, grimoire, according, methodists, boron,
# Nearest to only: hyperspace, have, chessboard, clockwise, gangs, glide, cyberpunk, urng,
# Nearest to years: seven, migration, total, rate, expectancy, male, children, hitchens,
# Nearest to he: his, hardened, buckle, draws, piqued, greenwood, belated, moments,
# Nearest to over: angleton, airports, orapa, bougainville, intend, uncharacteristic, longbows, dowland,
# Nearest to about: kowloon, audubon, historians, baralong, henslow, copernicus, kampf, islet,
# Nearest to taking: demosthenes, consented, coleridge, variance, immunosuppressive, electorate, prelude, junnin,
# Nearest to units: si, transposing, joule, diverted, emb, combustion, pdi, measurements,
# Nearest to professional: football, cyclopedia, franchises, express, introductions, expandability, lichtenstein, bernie,
# Nearest to file: download, platform, bundled, isdn, ega, collaboratively, astronautica, threaded,
# Nearest to behind: methadone, snap, stubby, overran, admonitions, abrasive, shotguns, inferiority,
# Nearest to consists: drain, ile, louisbourg, photonic, sukhothai, foggy, busiest, flags,
# Nearest to lived: rwandan, celibate, ruickbie, liguria, tempestuous, bibliotheke, svinhufvud, migrant,
# Nearest to marriage: payment, paid, preslar, wolfowitz, preside, chains, erechtheus, outrage,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0570 0.2917 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0913 0.2917 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0862 0.2907 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0472 0.2910 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.1037 0.2918 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0516 0.2907 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0769 0.2906 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.1035 0.2918 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1369 0.2904 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0378 0.2904 sec/batch
# Nearest to it: where, satisfiability, adrenergic, testable, jumpers, phaenomena, none, polypropylene,
# Nearest to can: private, superpowered, layer, subtracting, operas, miracles, primates, obstetrics,
# Nearest to also: gohan, strains, macgillivray, methodists, grier, nightmares, grimoire, according,
# Nearest to only: hyperspace, have, chessboard, clockwise, gangs, urng, they, possible,
# Nearest to years: seven, migration, total, rate, expectancy, male, hitchens, three,
# Nearest to he: his, hardened, buckle, draws, moments, ecumenical, piqued, belated,
# Nearest to over: angleton, airports, orapa, bougainville, longbows, lyotropic, intend, runs,
# Nearest to about: kowloon, historians, audubon, henslow, baralong, monotheist, mabo, islet,
# Nearest to taking: demosthenes, consented, coleridge, immunosuppressive, variance, prelude, dur, electorate,
# Nearest to units: transposing, si, joule, diverted, white, emb, pdi, makeup,
# Nearest to professional: football, cyclopedia, franchises, sanfl, expandability, association, express, introductions,
# Nearest to file: platform, ega, download, isdn, bundled, collaboratively, astronautica, threaded,
# Nearest to behind: methadone, snap, stubby, overran, admonitions, abrasive, shotguns, inferiority,
# Nearest to consists: drain, ile, louisbourg, photonic, sukhothai, foggy, busiest, flags,
# Nearest to lived: rwandan, celibate, ruickbie, liguria, bibliotheke, hercegovina, bayern, migrant,
# Nearest to marriage: payment, paid, preslar, wolfowitz, preside, chains, shelved, erechtheus,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0146 0.2942 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0445 0.2925 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0174 0.2913 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0475 0.2905 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0756 0.2909 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0732 0.2911 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0817 0.2913 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1033 0.2911 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0748 0.2911 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0624 0.2912 sec/batch
# Nearest to it: where, satisfiability, none, phaenomena, testable, adrenergic, jumpers, polypropylene,
# Nearest to can: private, operas, equivalence, layer, subtracting, primates, miracles, niva,
# Nearest to also: macgillivray, strains, methodists, gohan, grimoire, grier, in, gue,
# Nearest to only: have, hyperspace, clockwise, possible, chessboard, each, gangs, urng,
# Nearest to years: seven, migration, total, rate, expectancy, male, fifteen, population,
# Nearest to he: his, hardened, buckle, draws, piqued, belated, moments, corman,
# Nearest to over: airports, angleton, orapa, lyotropic, zero, dowland, relatedness, vouchers,
# Nearest to about: kowloon, historians, henslow, constructs, copernicus, monotheist, audubon, kalam,
# Nearest to taking: consented, demosthenes, coleridge, immunosuppressive, variance, electorate, prelude, wiggle,
# Nearest to units: si, transposing, joule, white, diverted, makeup, emb, pdi,
# Nearest to professional: football, franchises, cyclopedia, field, expandability, association, express, academic,
# Nearest to file: platform, ega, bundled, download, matlab, booting, collaboratively, carolyn,
# Nearest to behind: methadone, snap, stubby, overran, admonitions, sharply, abrasive, absinthe,
# Nearest to consists: drain, photonic, ile, louisbourg, sukhothai, foggy, subkey, fb,
# Nearest to lived: celibate, bibliotheke, ruickbie, tempestuous, bayern, rwandan, liguria, migrant,
# Nearest to marriage: payment, paid, wolfowitz, preslar, preside, chains, taxpayer, grandma,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0703 0.2929 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.1009 0.2919 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0520 0.2910 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0567 0.2899 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0867 0.2915 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0500 0.2908 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0749 0.2909 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0559 0.2914 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.1073 0.2906 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0697 0.2909 sec/batch
# Nearest to it: adrenergic, none, censorship, satisfiability, where, testable, pedophilia, jumpers,
# Nearest to can: private, operas, miracles, superpowered, you, primates, equivalence, subtracting,
# Nearest to also: gohan, methodists, liechtenstein, strains, macgillivray, grimoire, grier, in,
# Nearest to only: have, hyperspace, chessboard, possible, urng, gangs, clockwise, incapacity,
# Nearest to years: seven, migration, total, rate, expectancy, male, thirty, fifteen,
# Nearest to he: his, hardened, argument, buckle, draws, esteemed, belated, piqued,
# Nearest to over: angleton, airports, dowland, orapa, moonraker, zero, vouchers, hs,
# Nearest to about: historians, henslow, kidby, constructs, kowloon, monotheist, tycho, audubon,
# Nearest to taking: demosthenes, consented, coleridge, variance, immunosuppressive, prelude, electorate, dur,
# Nearest to units: si, transposing, joule, white, diverted, makeup, pdi, racial,
# Nearest to professional: football, franchises, field, cyclopedia, expandability, draw, introductions, association,
# Nearest to file: ega, matlab, collaboratively, download, bundled, platform, isdn, threaded,
# Nearest to behind: methadone, overran, snap, stubby, admonitions, inferiority, abrasive, sharply,
# Nearest to consists: drain, louisbourg, sukhothai, ile, foggy, photonic, saxony, fb,
# Nearest to lived: celibate, ruickbie, bayern, liguria, aramaeans, kanto, svinhufvud, hercegovina,
# Nearest to marriage: payment, paid, preslar, wolfowitz, chains, relationships, erechtheus, preside,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0515 0.2930 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0105 0.2909 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0292 0.2902 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0755 0.2918 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0630 0.2941 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1208 0.2922 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1453 0.2913 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0361 0.2909 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0409 0.2909 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0470 0.2902 sec/batch
# Nearest to it: none, where, scoreboard, satisfiability, truly, testable, pedophilia, landmasses,
# Nearest to can: private, operas, obstetrics, you, miracles, layer, primates, keyboard,
# Nearest to also: strains, liechtenstein, gohan, methodists, grier, grimoire, gue, macgillivray,
# Nearest to only: have, chessboard, hyperspace, urng, gangs, incapacity, clockwise, possible,
# Nearest to years: seven, migration, total, rate, expectancy, male, fifteen, hitchens,
# Nearest to he: his, hardened, graduating, draws, buckle, moments, him, jameson,
# Nearest to over: airports, orapa, angleton, dowland, bougainville, longbows, vouchers, zero,
# Nearest to about: historians, kowloon, henslow, mabo, udall, kidby, constructs, algorism,
# Nearest to taking: demosthenes, consented, coleridge, variance, immunosuppressive, brugha, congestion, wiggle,
# Nearest to units: si, transposing, joule, white, diverted, makeup, racial, pdi,
# Nearest to professional: football, franchises, field, cyclopedia, academic, draw, sanfl, lichtenstein,
# Nearest to file: ega, matlab, download, collaboratively, isdn, platform, carolyn, proxy,
# Nearest to behind: methadone, overran, snap, stubby, admonitions, sharply, inferiority, abrasive,
# Nearest to consists: drain, sukhothai, louisbourg, ile, saxony, photonic, foggy, distinguish,
# Nearest to lived: celibate, biographer, ruickbie, vicar, miscellanies, steadily, tempestuous, liguria,
# Nearest to marriage: payment, paid, preslar, relationships, chains, wolfowitz, shelved, erechtheus,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9953 0.2927 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0231 0.2927 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0513 0.2927 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0321 0.2917 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0936 0.2919 sec/batch
#  40%|████      | 4/10 [1:29:56<2:14:54, 1349.05s/it]
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0760 0.2565 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0187 0.2920 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9590 0.2912 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0199 0.2926 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9734 0.2920 sec/batch
# Nearest to it: none, where, testable, scoreboard, pedophilia, calculus, phaenomena, truly,
# Nearest to can: private, miracles, layer, primates, obstetrics, hammering, operas, niva,
# Nearest to also: in, strains, liechtenstein, gohan, methodists, macgillivray, grier, gue,
# Nearest to only: hyperspace, chessboard, have, possible, each, urng, clockwise, glide,
# Nearest to years: seven, migration, total, rate, expectancy, fifteen, male, thirty,
# Nearest to he: his, hardened, draws, graduating, esteemed, him, buckle, moments,
# Nearest to over: airports, dowland, orapa, angleton, longbows, bougainville, uncharacteristic, vouchers,
# Nearest to about: historians, mabo, kowloon, henslow, surveys, tycho, rut, kidby,
# Nearest to taking: demosthenes, consented, coleridge, variance, immunosuppressive, brugha, congestion, rescuing,
# Nearest to units: si, white, joule, transposing, makeup, racial, pdi, diverted,
# Nearest to professional: football, franchises, sanfl, field, cyclopedia, expandability, association, clostridium,
# Nearest to file: ega, matlab, collaboratively, download, isdn, carolyn, acquaintances, reform,
# Nearest to behind: methadone, snap, overran, stubby, sharply, admonitions, abrasive, inferiority,
# Nearest to consists: drain, louisbourg, sukhothai, ile, foggy, saxony, assembl, veto,
# Nearest to lived: celibate, died, ruickbie, vicar, biographer, miscellanies, hast, kanto,
# Nearest to marriage: payment, paid, preslar, relationships, chains, preside, wolfowitz, shelved,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0188 0.2936 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9639 0.2930 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0010 0.2924 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0321 0.2931 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0078 0.2914 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0126 0.2921 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9113 0.2922 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9641 0.2933 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9434 0.2919 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9753 0.2921 sec/batch
# Nearest to it: none, where, pedophilia, scoreboard, satisfiability, calculus, is, phaenomena,
# Nearest to can: private, keyboard, miracles, obstetrics, subtracting, primates, operas, you,
# Nearest to also: in, methodists, strains, liechtenstein, gohan, gue, macgillivray, youth,
# Nearest to only: hyperspace, have, chessboard, each, possible, clockwise, pigeons, personified,
# Nearest to years: seven, total, migration, rate, expectancy, male, three, population,
# Nearest to he: his, hardened, him, draws, moments, graduating, esteemed, buckle,
# Nearest to over: airports, orapa, years, zero, dowland, longbows, bougainville, vouchers,
# Nearest to about: mabo, kowloon, henslow, rut, historians, surveys, tycho, kidby,
# Nearest to taking: consented, demosthenes, coleridge, immunosuppressive, variance, dur, congestion, prelude,
# Nearest to units: si, white, makeup, racial, joule, transposing, pdi, diverted,
# Nearest to professional: football, field, franchises, sanfl, association, cyclopedia, expandability, draw,
# Nearest to file: matlab, ega, collaboratively, acquaintances, carolyn, homeworld, download, aphasia,
# Nearest to behind: methadone, snap, overran, stubby, sharply, admonitions, paddle, inferiority,
# Nearest to consists: louisbourg, drain, sukhothai, ile, assembl, photonic, mascarene, national,
# Nearest to lived: celibate, steadily, vicar, liguria, settlement, died, kanto, ruickbie,
# Nearest to marriage: payment, preslar, paid, relationships, chains, preside, erechtheus, wolfowitz,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0134 0.2943 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0041 0.2917 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9814 0.2915 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0082 0.2928 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 3.9918 0.2922 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9558 0.2917 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9940 0.2902 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0279 0.2905 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9771 0.2917 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9846 0.2909 sec/batch
# Nearest to it: none, where, satisfiability, testable, jumpers, pedophilia, calculus, scoreboard,
# Nearest to can: private, operas, you, equivalence, miracles, keyboard, subtracting, niva,
# Nearest to also: in, methodists, liechtenstein, lucia, strains, gohan, youth, grier,
# Nearest to only: hyperspace, have, chessboard, possible, each, clockwise, pigeons, check,
# Nearest to years: seven, migration, total, rate, expectancy, thirty, fifteen, male,
# Nearest to he: his, him, hardened, draws, graduating, diem, wants, esteemed,
# Nearest to over: airports, zero, dowland, orapa, angleton, vouchers, years, moonraker,
# Nearest to about: henslow, critique, historians, mabo, surveys, kowloon, kidby, rut,
# Nearest to taking: consented, demosthenes, coleridge, immunosuppressive, variance, prelude, congestion, brugha,
# Nearest to units: si, white, joule, makeup, racial, multiplications, transposing, residing,
# Nearest to professional: football, field, franchises, expandability, sanfl, academic, association, cyclopedia,
# Nearest to file: matlab, ega, collaboratively, download, proxy, acquaintances, flowcharts, homeworld,
# Nearest to behind: methadone, snap, overran, sharply, stubby, admonitions, inferiority, abrasive,
# Nearest to consists: drain, louisbourg, sukhothai, ile, assembl, photonic, subkey, referees,
# Nearest to lived: celibate, vicar, died, steadily, liguria, biographer, bayern, peril,
# Nearest to marriage: payment, relationships, preslar, paid, chains, taxpayer, preside, wolfowitz,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0161 0.2928 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9611 0.2919 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 4.0127 0.2921 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9901 0.2918 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0105 0.2921 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9688 0.2917 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9943 0.2910 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9873 0.2903 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9695 0.2911 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0165 0.2934 sec/batch
# Nearest to it: none, where, satisfiability, is, ecoregions, censorship, calculus, jumpers,
# Nearest to can: private, miracles, you, obstetrics, niva, operas, equivalence, primates,
# Nearest to also: in, liechtenstein, methodists, lucia, strains, gohan, and, the,
# ...
# Epoch 6/10 Iteration: 25300 Avg. Training loss: 3.9104 0.2917 sec/batch
# Epoch 6/10 Iteration: 25400 Avg. Training loss: 3.9373 0.2913 sec/batch
# Epoch 6/10 Iteration: 25500 Avg. Training loss: 3.9619 0.2909 sec/batch
# Epoch 6/10 Iteration: 25600 Avg. Training loss: 3.9211 0.2919 sec/batch
# Epoch 6/10 Iteration: 25700 Avg. Training loss: 3.9450 0.2913 sec/batch
# Epoch 6/10 Iteration: 25800 Avg. Training loss: 3.9167 0.2921 sec/batch
# Epoch 6/10 Iteration: 25900 Avg. Training loss: 3.9362 0.2913 sec/batch
# Epoch 6/10 Iteration: 26000 Avg. Training loss: 3.9594 0.2912 sec/batch
# Nearest to it: is, none, calculus, where, censorship, satisfiability, a, calvinist,
# Nearest to can: operas, private, you, equivalence, obstetrics, miracles, seventy, synergies,
# Nearest to also: in, liechtenstein, methodists, the, lucia, and, of, youth,
# Nearest to only: hyperspace, have, chessboard, pigeons, possible, conviction, they, each,
# Nearest to years: seven, migration, rate, expectancy, thirty, fifteen, total, male,
# Nearest to he: his, graduating, was, him, esteemed, returned, masters, apprenticed,
# Nearest to over: zero, airports, years, dowland, five, female, ratio, six,
# Nearest to about: historians, surveys, mabo, henslow, critique, than, kidby, bibliographic,
# Nearest to taking: consented, demosthenes, coleridge, immunosuppressive, wiggle, congestion, variance, rescuing,
# Nearest to units: si, white, racial, makeup, joule, residing, multiplications, aspectual,
# Nearest to professional: football, franchises, expandability, field, sanfl, academic, training, draw,
# Nearest to file: matlab, ega, download, acquaintances, collaboratively, replies, flowcharts, proxy,
# Nearest to behind: methadone, snap, sharply, overran, inferiority, abrasive, stubby, paddle,
# Nearest to consists: louisbourg, sukhothai, ile, drain, zircon, assembl, referees, subkey,
# Nearest to lived: celibate, died, vicar, settlement, machpelah, kanto, migrant, hast,
# Nearest to marriage: relationships, preslar, payment, chains, paid, erechtheus, heiner, majorca,
# Epoch 6/10 Iteration: 26100 Avg. Training loss: 3.9332 0.2939 sec/batch
# Epoch 6/10 Iteration: 26200 Avg. Training loss: 3.9315 0.2912 sec/batch
# Epoch 6/10 Iteration: 26300 Avg. Training loss: 3.9582 0.2908 sec/batch
# Epoch 6/10 Iteration: 26400 Avg. Training loss: 3.9473 0.2914 sec/batch
# Epoch 6/10 Iteration: 26500 Avg. Training loss: 3.9232 0.2902 sec/batch
# Epoch 6/10 Iteration: 26600 Avg. Training loss: 3.9754 0.2913 sec/batch
# Epoch 6/10 Iteration: 26700 Avg. Training loss: 3.9431 0.2916 sec/batch
# Epoch 6/10 Iteration: 26800 Avg. Training loss: 4.0271 0.2919 sec/batch
# Epoch 6/10 Iteration: 26900 Avg. Training loss: 3.9929 0.2912 sec/batch
# Epoch 6/10 Iteration: 27000 Avg. Training loss: 3.9991 0.2906 sec/batch
# Nearest to it: is, none, where, a, calculus, the, censorship, so,
# Nearest to can: operas, primates, private, manna, seventy, obstetrics, miracles, interrogated,
# Nearest to also: in, liechtenstein, the, lucia, methodists, and, of, grier,
# Nearest to only: hyperspace, have, pigeons, chessboard, possible, they, riverbed, bautista,
# Nearest to years: seven, migration, rate, thirty, fifteen, expectancy, total, over,
# Nearest to he: his, graduating, him, was, returned, esteemed, draws, wants,
# Nearest to over: airports, years, zero, dowland, oper, female, at, ratio,
# Nearest to about: surveys, henslow, critique, historians, mabo, kidby, five, udall,
# Nearest to taking: consented, demosthenes, coleridge, wiggle, rescuing, congestion, immunosuppressive, variance,
# Nearest to units: si, racial, white, makeup, joule, residing, pdi, multiplications,
# Nearest to professional: football, franchises, sanfl, field, expandability, academic, training, jason,
# Nearest to file: matlab, ega, download, acquaintances, collaboratively, replies, worships, proxy,
# Nearest to behind: methadone, sharply, snap, overran, inferiority, stubby, admonitions, abrasive,
# Nearest to consists: ile, drain, louisbourg, zircon, sukhothai, assembl, amazonia, photonic,
# Nearest to lived: died, celibate, vicar, settlement, steadily, migrant, machpelah, kanto,
# Nearest to marriage: relationships, preslar, payment, chains, paid, sister, erechtheus, intercourse,
# Epoch 6/10 Iteration: 27100 Avg. Training loss: 3.9308 0.2936 sec/batch
# Epoch 6/10 Iteration: 27200 Avg. Training loss: 3.8780 0.2905 sec/batch
# Epoch 6/10 Iteration: 27300 Avg. Training loss: 3.9621 0.2908 sec/batch
# Epoch 6/10 Iteration: 27400 Avg. Training loss: 3.8500 0.2914 sec/batch
# Epoch 6/10 Iteration: 27500 Avg. Training loss: 3.9740 0.2914 sec/batch
# Epoch 6/10 Iteration: 27600 Avg. Training loss: 3.9354 0.2923 sec/batch
# Epoch 6/10 Iteration: 27700 Avg. Training loss: 3.9440 0.2915 sec/batch
#  60%|██████    | 6/10 [2:14:56<1:29:57, 1349.39s/it]
# Epoch 7/10 Iteration: 27800 Avg. Training loss: 3.9714 0.0938 sec/batch
# Epoch 7/10 Iteration: 27900 Avg. Training loss: 3.9058 0.2911 sec/batch
# Epoch 7/10 Iteration: 28000 Avg. Training loss: 3.9177 0.2913 sec/batch
# Nearest to it: is, calculus, none, where, a, landmasses, calvinist, censorship,
# Nearest to can: operas, primates, seventy, hazardous, private, manna, layer, niva,
# Nearest to also: in, the, liechtenstein, of, and, as, methodists, strains,
# Nearest to only: hyperspace, chessboard, pigeons, riverbed, they, have, each, possible,
# Nearest to years: migration, seven, rate, thirty, total, fifteen, expectancy, over,
# Nearest to he: his, graduating, him, draws, esteemed, returned, was, friend,
# Nearest to over: airports, years, zero, dowland, ratio, female, oper, at,
# Nearest to about: surveys, henslow, critique, kidby, than, historians, tycho, mabo,
# Nearest to taking: consented, demosthenes, coleridge, variance, rescuing, angola, immunosuppressive, congestion,
# Nearest to units: si, racial, makeup, joule, white, residing, multiplications, aspectual,
# Nearest to professional: football, franchises, field, sanfl, training, expandability, academic, uy,
# Nearest to file: matlab, ega, download, acquaintances, collaboratively, vocal, sheets, replies,
# Nearest to behind: methadone, snap, sharply, inferiority, stubby, abrasive, overran, paddle,
# Nearest to consists: ile, louisbourg, sukhothai, referees, assembl, unicameral, zircon, consisting,
# Nearest to lived: died, celibate, vicar, settlement, steadily, hydrologic, migrant, machpelah,
# Nearest to marriage: relationships, preslar, payment, chains, paid, preside, sister, marriages,
# Epoch 7/10 Iteration: 28100 Avg. Training loss: 3.8877 0.2942 sec/batch
# Epoch 7/10 Iteration: 28200 Avg. Training loss: 3.9166 0.2905 sec/batch
# Epoch 7/10 Iteration: 28300 Avg. Training loss: 3.9240 0.2911 sec/batch
# Epoch 7/10 Iteration: 28400 Avg. Training loss: 3.9325 0.2911 sec/batch
# Epoch 7/10 Iteration: 28500 Avg. Training loss: 3.8519 0.2903 sec/batch
# Epoch 7/10 Iteration: 28600 Avg. Training loss: 3.9332 0.2914 sec/batch
# Epoch 7/10 Iteration: 28700 Avg. Training loss: 3.9532 0.2912 sec/batch
# Epoch 7/10 Iteration: 28800 Avg. Training loss: 3.9611 0.2911 sec/batch
# Epoch 7/10 Iteration: 28900 Avg. Training loss: 3.8317 0.2913 sec/batch
# Epoch 7/10 Iteration: 29000 Avg. Training loss: 3.8697 0.2906 sec/batch
# Nearest to it: is, none, where, calculus, the, a, third, so,
# Nearest to can: primates, operas, hazardous, seventy, unable, all, you, manna,
# Nearest to also: in, the, and, of, liechtenstein, as, with, methodists,
# Nearest to only: have, possible, each, they, hyperspace, pigeons, chessboard, in,
# Nearest to years: seven, migration, rate, thirty, total, five, zero, over,
# Nearest to he: his, graduating, him, esteemed, perfectly, returned, arraignment, hardened,
# Nearest to over: years, airports, zero, five, female, ratio, at, dowland,
# Nearest to about: surveys, henslow, five, than, bridgewater, mabo, anachronisms, kidby,
# Nearest to taking: consented, demosthenes, coleridge, rescuing, immunosuppressive, variance, wiggle, batista,
# Nearest to units: si, racial, white, makeup, joule, residing, transposing, multiplications,
# Nearest to professional: football, training, franchises, sanfl, field, expandability, academic, uy,
# Nearest to file: matlab, acquaintances, ega, download, homeworld, sheets, replies, vocal,
# Nearest to behind: methadone, snap, sharply, inferiority, overran, abrasive, stubby, paddle,
# Nearest to consists: by, louisbourg, consisting, ile, assembl, amazonia, national, zircon,
# Nearest to lived: died, celibate, settlement, vicar, steadily, migrant, hydrologic, machpelah,
# Nearest to marriage: relationships, preslar, payment, chains, marriages, paid, preside, marry,
# Epoch 7/10 Iteration: 29100 Avg. Training loss: 3.8823 0.2932 sec/batch
# Epoch 7/10 Iteration: 29200 Avg. Training loss: 3.8581 0.2907 sec/batch
# Epoch 7/10 Iteration: 29300 Avg. Training loss: 3.9082 0.2910 sec/batch
# Epoch 7/10 Iteration: 29400 Avg. Training loss: 3.9191 0.2911 sec/batch
# Epoch 7/10 Iteration: 29500 Avg. Training loss: 3.8931 0.2895 sec/batch
# Epoch 7/10 Iteration: 29600 Avg. Training loss: 3.8939 0.2907 sec/batch
# Epoch 7/10 Iteration: 29700 Avg. Training loss: 3.9847 0.2911 sec/batch
# Epoch 7/10 Iteration: 29800 Avg. Training loss: 3.8865 0.2911 sec/batch
# Epoch 7/10 Iteration: 29900 Avg. Training loss: 3.8742 0.2909 sec/batch
# Epoch 7/10 Iteration: 30000 Avg. Training loss: 3.9101 0.2906 sec/batch
# Nearest to it: is, a, the, none, where, calculus, third, calvinist,
# Nearest to can: operas, primates, you, hazardous, unable, private, difference, seventy,
# Nearest to also: in, the, and, of, liechtenstein, as, methodists, with,
# Nearest to only: have, possible, hyperspace, they, pigeons, each, chessboard, bautista,
# Nearest to years: seven, migration, thirty, rate, total, expectancy, fifteen, zero,
# Nearest to he: his, graduating, him, esteemed, arraignment, returned, wrote, friend,
# Nearest to over: zero, years, airports, ratio, five, dowland, six, female,
# Nearest to about: henslow, surveys, what, critique, kidby, anachronisms, historians, than,
# Nearest to taking: consented, demosthenes, coleridge, immunosuppressive, wiggle, variance, rescuing, congestion,
# Nearest to units: si, makeup, racial, joule, white, residing, transposing, multiplications,
# Nearest to professional: football, training, franchises, sanfl, expandability, academic, uy, field,
# Nearest to file: matlab, ega, download, acquaintances, proxy, replies, homeworld, sheets,
# Nearest to behind: methadone, snap, sharply, inferiority, overran, stubby, paddle, abrasive,
# Nearest to consists: assembl, consisting, zircon, louisbourg, referees, by, amazonia, ile,
# Nearest to lived: died, celibate, vicar, settlement, machpelah, family, migrant, flores,
# Nearest to marriage: relationships, preslar, chains, payment, marry, marriages, preside, intercourse,
# Epoch 7/10 Iteration: 30100 Avg. Training loss: 3.9291 0.2929 sec/batch
# Epoch 7/10 Iteration: 30200 Avg. Training loss: 3.9160 0.2918 sec/batch
# Epoch 7/10 Iteration: 30300 Avg. Training loss: 3.8870 0.2910 sec/batch
# Epoch 7/10 Iteration: 30400 Avg. Training loss: 3.8916 0.2919 sec/batch
# Epoch 7/10 Iteration: 30500 Avg. Training loss: 3.9016 0.2918 sec/batch
# Epoch 7/10 Iteration: 30600 Avg. Training loss: 3.8910 0.2916 sec/batch
# Epoch 7/10 Iteration: 30700 Avg. Training loss: 3.9189 0.2934 sec/batch
# Epoch 7/10 Iteration: 30800 Avg. Training loss: 3.9298 0.2913 sec/batch
# Epoch 7/10 Iteration: 30900 Avg. Training loss: 3.8833 0.2915 sec/batch
# Epoch 7/10 Iteration: 31000 Avg. Training loss: 3.9129 0.2913 sec/batch
# Nearest to it: is, the, none, where, a, third, calculus, so,
# Nearest to can: operas, primates, interrogated, you, private, sonority, hazardous, seventy,
# Nearest to also: in, the, and, liechtenstein, of, as, methodists, with,
# Nearest to only: hyperspace, possible, pigeons, chessboard, have, bautista, they, riverbed,
# Nearest to years: seven, migration, thirty, rate, total, expectancy, fifteen, remaining,
# Nearest to he: his, graduating, him, returned, esteemed, wrote, was, arraignment,
# Nearest to over: zero, years, airports, five, female, ratio, dowland, six,
# Nearest to about: critique, historians, what, henslow, five, than, surveys, kidby,
# Nearest to taking: demosthenes, consented, coleridge, rescuing, batista, wiggle, congestion, immigrants,
# Nearest to units: si, makeup, racial, joule, residing, white, transposing, aspectual,
# Nearest to professional: football, training, franchises, expandability, academic, sanfl, nicklaus, field,
# Nearest to file: ega, matlab, acquaintances, download, proxy, replies, vocal, sheets,
# Nearest to behind: methadone, overran, sharply, snap, inferiority, stubby, account, abrasive,
# Nearest to consists: zircon, consisting, louisbourg, by, assembl, amazonia, ile, sukhothai,
# Nearest to lived: died, celibate, settlement, vicar, family, steadily, kanto, migrant,
# Nearest to marriage: relationships, preslar, chains, payment, marry, marriages, intercourse, marrying,
# Epoch 7/10 Iteration: 31100 Avg. Training loss: 3.8728 0.2929 sec/batch
# Epoch 7/10 Iteration: 31200 Avg. Training loss: 3.9158 0.2915 sec/batch
# Epoch 7/10 Iteration: 31300 Avg. Training loss: 3.9295 0.2931 sec/batch
# Epoch 7/10 Iteration: 31400 Avg. Training loss: 3.9342 0.2916 sec/batch
# Epoch 7/10 Iteration: 31500 Avg. Training loss: 4.0034 0.2917 sec/batch
#  60%|██████    | 6/10 [2:33:19<1:42:13, 1533.27s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-48-c7e33bdef951> in <module>()
#      17
#      18             feed = {inputs: x, labels: np.array(y)[:, None]}
# ---> 19             train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
#      20
#      21             loss += train_loss
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     969     try:
#     970       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 971                          run_metadata_ptr)
#     972       if run_metadata:
#     973         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1192     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1193       results = self._do_run(handle, final_targets, final_fetches,
# -> 1194                              feed_dict_tensor, options, run_metadata)
#    1195     else:
#    1196       results = []
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1372     if handle is None:
#    1373       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1374                            run_metadata)
#    1375     else:
#    1376       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1378   def _do_call(self, fn, *args):
#    1379     try:
# -> 1380       return fn(*args)
#    1381     except errors.OpError as e:
#    1382       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1362       self._extend_graph()
#    1363       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
# -> 1364                                       target_list, run_metadata)
#    1365
#    1366     def _prun_fn(handle, feed_dict, fetch_list):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1456     return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
#    1457                                             fetch_list, target_list,
# -> 1458                                             run_metadata)
#    1459
#    1460   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
